# %%
print("hello, world")
# Out:
# hello, world

# %%
# Bug → missing closing parenthesis
print("Hello, World!"
# Out:
#   Cell In[32], line 2
#     print("Hello, World!"
#                             ^
# SyntaxError: incomplete input

# %% [markdown]
# **input**

# %%
input("What's your name? ")
print("hello, world")

# %%
input("What's your name? ")
print("hello, Avinash")
# Out:
# hello, Avinash

# %%
name = input("what's your name? ")
print('hello,name')
# Out:
# hello,name

# %%
name = input("what's your name? ")
print('hello,')
print(name)
# Out:
# hello,
# Avinash

# %%
name = input("what's your name? ")
print('hello, ' + name)
# Out:
# hello, Avinash

# %%
name = input("what's your name? ")
print('hello, ',name)
# Out:
# hello,  Avinash

# %%
name = input("what's your name? ")
print('hello,',name)
# Out:
# hello, Avinash

# %%
name = input("what's your name? ")
print('hello, ', end="")
print(name)
# Out:
# hello, Avinash

# %%
name = input("what's your name? ")
print('hello,',name, sep="??")
# Out:
# hello,??Avinash

# %%
print('hello,"freind"')
print("hello,\"freind\"")
# Out:
# hello,"freind"
# hello,"freind"

# %% [markdown]
# **String**

# %%
name = input("what's your name? ")
print(f"hello, {name}")
# Out:
# hello,                  Avinash

# %%
name = input("what's your name? ")
name = name.strip()
print(f"hello, {name}")
# Out:
# hello, Avinash

# %%
name = input("what's your name? ")
name = name.strip()
name = name.title()
print(f"hello, {name}")
# Out:
# hello, Avinash Singh

# %%
name = input("what's your name? ")
name = name.strip().title()
print(f"hello, {name}")
# Out:
# hello, Avinash Singh

# %%
name = input("what's your name? ").strip().title()
print(f"hello, {name}")
# Out:
# hello, Avinash Singh

# %%
name = input("what's your name? ").strip().title()
first, last = name.split()
print(f"hello, {first}")
# Out:
# hello, Avinash

# %% [markdown]
# **Numbers**

# %%
x = 1
y = 2
z = x + y
print(z)
# Out:
# 3

# %%
x = input("what's x? ") 
y = input("what's y? ")
z = x + y
print(z)
# Out:
# 1212

# %%
x = input("what's x? ") 
y = input("what's y? ")
z = int(x) + int(y)
print(z)
# Out:
# 24

# %%
x = int(input("what's x? "))
y = int(input("what's y? "))
print(x + y)
# Out:
# 24

# %%
int(input("what's x? ")) + int(input("what's y? "))
# Out:
# 24

# %%
x = float(input("what's x? "))
y = float(input("what's y? "))
z = round(x+y)
print(z)
# Out:
# 5

# %%
x = float(input("what's x? "))
y = float(input("what's y? "))
z = round(x+y)
print(z)
# Out:
# 1000

# %%
print(f"{z:,}")
# Out:
# 1,000

# %%
print(f"{z:.2f}")
# Out:
# 1000.00

# %% [markdown]
# **funcation**

# %%
name = input("what's your name? ")
hello()
print(name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 name = input("what's your name? ")
# ----> 2 hello()
#       3 print(name)
#
# NameError: name 'hello' is not defined

# %%
def hello():
    print("hello")
name = input("what's your name? ")
hello()
print(name)
# Out:
# hello
# Avinash

# %%
def hello(to):
    print("hello,", to)
    
name = input("what's your name? ")
hello(name)
# Out:
# hello, Avinash

# %%
def hello(to='world'):
    print("hello,", to)
    
hello()    
name = input("what's your name? ")
hello(name)
# Out:
# hello, world
# hello, avinash

# %%
def main():
    name = input("what's your name?" )
    hello(name)
def hello(to='world'):
    print('hello,',to)

main()
# Out:
# hello, Avinash

# %%
def main():
    name = input("what's your name?" )
    hello()
def hello():
    print('hello,',name)

main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       3     hello()
#       4 def hello():
#       5     print('hello,',name)
#       6
# ----> 7 main()
#
# Cell In[1], line 3, in main()
#       1 def main():
#       2     name = input("what's your name?" )
# ----> 3     hello()
#
# Cell In[1], line 5, in hello()
#       4 def hello():
# ----> 5     print('hello,',name)
#
# NameError: name 'name' is not defined
