# %%
import pandas as pd
import seaborn as sns

# %%
path = "dataset/train.csv"
df = pd.read_csv(path)
df = df.drop(columns=["id"])
df.head()
# Out:
#            brand              model  model_year  milage      fuel_type  \
# 0           MINI      Cooper S Base        2007  213000       Gasoline
# 1        Lincoln              LS V8        2002  143250       Gasoline
# 2      Chevrolet  Silverado 2500 LT        2002  136731  E85 Flex Fuel
# 3        Genesis   G90 5.0 Ultimate        2017   19500       Gasoline
# 4  Mercedes-Benz        Metris Base        2021    7388       Gasoline
#
#                                               engine  \
# 0       172.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 1       252.0HP 3.9L 8 Cylinder Engine Gasoline Fuel
# 2  320.0HP 5.3L 8 Cylinder Engine Flex Fuel Capab...
# 3       420.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 4       208.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
#
#                      transmission ext_col int_col  \
# 0                             A/T  Yellow    Gray
# 1                             A/T  Silver   Beige
# 2                             A/T    Blue    Gray
# ...

# %%
# shape of data
df.shape
# Out:
# (188533, 12)

# %%
# information about the data
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 188533 entries, 0 to 188532
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   brand         188533 non-null  str
#  1   model         188533 non-null  str
#  2   model_year    188533 non-null  int64
#  3   milage        188533 non-null  int64
#  4   fuel_type     183450 non-null  str
#  5   engine        188533 non-null  str
#  6   transmission  188533 non-null  str
#  7   ext_col       188533 non-null  str
#  8   int_col       188533 non-null  str
#  9   accident      186081 non-null  str
#  10  clean_title   167114 non-null  str
#  11  price         188533 non-null  int64
# dtypes: int64(3), str(9)
# memory usage: 17.3 MB

# %%
# missing values
missing_values_summary = pd.DataFrame({
    "count": df.isna().sum(),
    "percentage": round(df.isna().mean() * 100, 2)
})

missing_values_summary
# Out:
#               count  percentage
# brand             0        0.00
# model             0        0.00
# model_year        0        0.00
# milage            0        0.00
# fuel_type      5083        2.70
# engine            0        0.00
# transmission      0        0.00
# ext_col           0        0.00
# int_col           0        0.00
# accident       2452        1.30
# clean_title   21419       11.36
# price             0        0.00

# %%
df[df.isna().any(axis=1)]
# Out:
#                 brand                                      model  model_year  \
# 11              Tesla                              Model S P100D        2015
# 20               Land                           Rover Defender S        2023
# 32              Tesla                              Model S P100D        2018
# 45                RAM                               1500 Laramie        2022
# 51              Tesla                         Model 3 Long Range        2020
# ...               ...                                        ...         ...
# 188507      Chevrolet                    Corvette Stingray w/3LT        2023
# 188511           Land  Rover Range Rover Velar P380 SE R-Dynamic        2022
# 188513          Lexus                             GS 350 F Sport        2022
# 188520  Mercedes-Benz                            GLC 300 GLC 300        2022
# 188531           Audi                           S5 3.0T Prestige        2022
#
# ...

# %%
df.loc[df["fuel_type"].isna(),["brand","engine"]].value_counts().head()
# Out:
# brand   engine
# Tesla   518.0HP Electric Motor Electric Fuel System    743
#         425.0HP Electric Motor Electric Fuel System    644
#         455.0HP Electric Motor Electric Fuel System    463
# Rivian  835.0HP Electric Motor Electric Fuel System    433
# Tesla   670.0HP Electric Motor Electric Fuel System    280
# Name: count, dtype: int64

# %%
df[df["fuel_type"].isna()]["engine"].str.contains(
    "Electric",
    case=False,
    na=False
).mean()
# Out:
# np.float64(0.9565217391304348)

# %%
df["accident"].value_counts(dropna=False)
# Out:
# accident
# None reported                             144514
# At least 1 accident or damage reported     41567
# NaN                                         2452
# Name: count, dtype: int64

# %%
df[df["accident"].isna()]["brand"]
# Out:
# 87                  RAM
# 134                Jeep
# 164               Acura
# 333       Mercedes-Benz
# 361                 RAM
#               ...
# 187885        Chevrolet
# 188140        Chevrolet
# 188425            Volvo
# 188505             Ford
# 188507        Chevrolet
# Name: brand, Length: 2452, dtype: str

# %%
df[df["accident"].isna()].describe()
# Out:
#         model_year         milage         price
# count  2452.000000    2452.000000  2.452000e+03
# mean   2017.300163   50269.850734  5.490299e+04
# std       5.577505   44729.872494  1.018028e+05
# min    1974.000000     159.000000  2.000000e+03
# 25%    2015.000000   15192.250000  2.300000e+04
# 50%    2019.000000   36728.500000  3.899900e+04
# 75%    2021.000000   73690.000000  6.091925e+04
# max    2024.000000  402000.000000  2.954083e+06

# %%
df[df["accident"].isna()].describe(include='str')
# Out:
#        brand      model fuel_type                 engine transmission ext_col  \
# count   2452       2452      2383                   2452         2452    2452
# unique    49        940         6                    591           36     173
# top     Ford  F-150 XLT  Gasoline  3.6L V6 24V MPFI DOHC          A/T   Black
# freq     322         60      2087                    106          384     539
#
#        int_col accident clean_title
# count     2452        0          14
# unique      82        0           1
# top      Black      NaN         Yes
# freq      1337      NaN          14
